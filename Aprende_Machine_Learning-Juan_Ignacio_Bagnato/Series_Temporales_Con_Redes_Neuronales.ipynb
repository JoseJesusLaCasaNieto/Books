# %% [markdown]
# # Pronóstico de Series Temporales con Redes Neuronales

# %% [markdown]
# ## 1. Cargar el ejemplo con Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('fast')
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.preprocessing import MinMaxScaler
import requests
from io import StringIO

url = 'https://raw.githubusercontent.com/jbagnato/machine-learning/master/time_series.csv'

response = requests.get(url)
csv_content = StringIO(response.text)

df = pd.read_csv(
    csv_content,
    parse_dates=[0],
    header=None,
    index_col=0,
    names=['fecha', 'unidades']
)
df.head()
# Out:
#             unidades
# fecha
# 2017-01-02       236
# 2017-01-03       237
# 2017-01-04       290
# 2017-01-05       221
# 2017-01-07       128

# %%
print(df.index.min())
print(df.index.max())
# Out:
# 2017-01-02 00:00:00
# 2018-11-30 00:00:00

# %%
print(len(df.loc['2017']))
print(len(df.loc['2018']))
# Out:
# 315
# 289

# %% [markdown]
# ## 2. Visualización de datos

# %%
df.describe()
# Out:
#          unidades
# count  604.000000
# mean   215.935430
# std     75.050304
# min     51.000000
# 25%    171.000000
# 50%    214.000000
# 75%    261.250000
# max    591.000000

# %%
meses = df.resample('M').mean()
meses
# Out:
# C:\Users\pepel\AppData\Local\Temp\ipykernel_7260\3818076977.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   meses = df.resample('M').mean()
#               unidades
# fecha
# 2017-01-31  203.923077
# 2017-02-28  184.666667
# 2017-03-31  182.964286
# 2017-04-30  198.960000
# 2017-05-31  201.185185
# 2017-06-30  209.518519
# 2017-07-31  278.923077
# 2017-08-31  316.000000
# 2017-09-30  222.925926
# 2017-10-31  207.851852
# 2017-11-30  185.925926
# 2017-12-31  213.200000
# 2018-01-31  201.384615
# 2018-02-28  190.625000
# 2018-03-31  174.846154
# 2018-04-30  186.000000
# 2018-05-31  190.666667
# 2018-06-30  196.037037
# 2018-07-31  289.500000
# 2018-08-31  309.038462
# 2018-09-30  230.518519
# 2018-10-31  209.444444
# 2018-11-30  184.481481

# %%
plt.plot(meses.loc['2017'].values)
plt.plot(meses.loc['2018'].values)

# %%
verano2017 = df['2017-06-01':'2017-09-01']
plt.plot(verano2017.values)
verano2018 = df['2018-06-01':'2018-09-01']
plt.plot(verano2018.values)

# %% [markdown]
# ## 3. Pronóstico de Ventas Diarias con Redes Neuronales

# %% [markdown]
# ### 3.1. Preparamos los datos

# %%
PASOS = 7

# Convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # Input sequence (t-n, ..., t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        # Forecast sequence (t, t+1, ..., t+n)
        for i in range(0, n_out):
            cols.append(df.shift(-i))
            if i==0:
                names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
            else:
                names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# Load dataset
values = df.values
# Ensure all data is float
values = values.astype('float32')
# Normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values = values.reshape(-1, 1)  # Esto lo hacemos porque tenemos una sola dimensión
scaled = scaler.fit_transform(values)
# Frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-7)   var1(t)  var1(t-6)   var1(t)  var1(t-5)   var1(t)  var1(t-4)  \
# 7   -0.314815 -0.433333  -0.311111 -0.433333  -0.114815 -0.433333  -0.370370
# 8   -0.311111 -0.607407  -0.114815 -0.607407  -0.370370 -0.607407  -0.714815
# 9   -0.114815 -0.522222  -0.370370 -0.522222  -0.714815 -0.522222  -0.103704
# 10  -0.370370 -0.644444  -0.714815 -0.644444  -0.103704 -0.644444  -0.225926
# 11  -0.714815 -0.344444  -0.103704 -0.344444  -0.225926 -0.344444  -0.433333
#
#      var1(t)  var1(t-3)   var1(t)  var1(t-2)   var1(t)  var1(t-1)   var1(t)
# 7  -0.433333  -0.714815 -0.433333  -0.103704 -0.433333  -0.225926 -0.433333
# 8  -0.607407  -0.103704 -0.607407  -0.225926 -0.607407  -0.433333 -0.607407
# 9  -0.522222  -0.225926 -0.522222  -0.433333 -0.522222  -0.607407 -0.522222
# 10 -0.644444  -0.433333 -0.644444  -0.607407 -0.644444  -0.522222 -0.644444
# 11 -0.344444  -0.607407 -0.344444  -0.522222 -0.344444  -0.644444 -0.344444

# %% [markdown]
# ### 3.2. Creamos la Red Neuronal Artificial

# %%
# Split into train and test sets
values = reframed.values
n_train_days = 315+289 - (30+PASOS)
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# Split into input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# Reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (567, 1, 13) (567,) (30, 1, 13) (30,)

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(13, input_shape=(1, 13), activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error', optimizer='Adam', metrics=['mse'])
    model.summary()
    return model

# %% [markdown]
# ### 3.3. Entrenamiento y Resultados

# %%
EPOCHS = 40

model = crear_modeloFF()

history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_val, y_val), batch_size=PASOS)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1, 13)             182
#
#  flatten_2 (Flatten)         (None, 13)                0
#
#  dense_5 (Dense)             (None, 1)                 14
#
# =================================================================
# Total params: 196
# Trainable params: 196
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 2s 3ms/step - loss: 0.1661 - mse: 0.0492 - val_loss: 0.0902 - val_mse: 0.0125
# Epoch 2/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0077 - val_loss: 0.0462 - val_mse: 0.0039
# Epoch 3/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0393 - mse: 0.0032 - val_loss: 0.0389 - val_mse: 0.0035
# Epoch 4/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0320 - mse: 0.0023 - val_loss: 0.0361 - val_mse: 0.0027
# Epoch 5/40
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0287 - mse: 0.0019 - val_loss: 0.0340 - val_mse: 0.0021
# Epoch 6/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0275 - mse: 0.0017 - val_loss: 0.0307 - val_mse: 0.0020
# Epoch 7/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0281 - mse: 0.0017 - val_loss: 0.0287 - val_mse: 0.0020
# Epoch 8/40
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0241 - mse: 0.0014 - val_loss: 0.0319 - val_mse: 0.0017
# Epoch 9/40
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0264 - mse: 0.0015 - val_loss: 0.0323 - val_mse: 0.0017
# Epoch 10/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0231 - mse: 0.0013 - val_loss: 0.0252 - val_mse: 0.0016
# Epoch 11/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0221 - mse: 0.0012 - val_loss: 0.0247 - val_mse: 0.0014
# Epoch 12/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0220 - mse: 0.0012 - val_loss: 0.0304 - val_mse: 0.0019
# Epoch 13/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0218 - mse: 0.0012 - val_loss: 0.0279 - val_mse: 0.0017
# Epoch 14/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0200 - mse: 0.0011 - val_loss: 0.0234 - val_mse: 0.0014
# Epoch 15/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0199 - mse: 0.0011 - val_loss: 0.0228 - val_mse: 0.0013
# Epoch 16/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0201 - mse: 0.0010 - val_loss: 0.0234 - val_mse: 0.0013
# Epoch 17/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0194 - mse: 0.0010 - val_loss: 0.0228 - val_mse: 0.0011
# Epoch 18/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0191 - mse: 9.4388e-04 - val_loss: 0.0210 - val_mse: 0.0011
# Epoch 19/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0190 - mse: 9.4929e-04 - val_loss: 0.0213 - val_mse: 0.0010
# Epoch 20/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0198 - mse: 9.6241e-04 - val_loss: 0.0230 - val_mse: 0.0010
# Epoch 21/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0186 - mse: 8.9977e-04 - val_loss: 0.0225 - val_mse: 9.6943e-04
# Epoch 22/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0183 - mse: 8.6774e-04 - val_loss: 0.0204 - val_mse: 0.0011
# Epoch 23/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 8.5377e-04 - val_loss: 0.0200 - val_mse: 9.8509e-04
# Epoch 24/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0182 - mse: 8.6021e-04 - val_loss: 0.0206 - val_mse: 9.2781e-04
# Epoch 25/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0192 - mse: 8.9247e-04 - val_loss: 0.0186 - val_mse: 0.0010
# Epoch 26/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0170 - mse: 8.0377e-04 - val_loss: 0.0211 - val_mse: 9.3252e-04
# Epoch 27/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0170 - mse: 7.9755e-04 - val_loss: 0.0192 - val_mse: 0.0011
# Epoch 28/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0183 - mse: 8.2884e-04 - val_loss: 0.0186 - val_mse: 8.6862e-04
# Epoch 29/40
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0174 - mse: 7.8234e-04 - val_loss: 0.0185 - val_mse: 8.6269e-04
# Epoch 30/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0167 - mse: 7.8941e-04 - val_loss: 0.0213 - val_mse: 9.2051e-04
# Epoch 31/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0173 - mse: 7.6315e-04 - val_loss: 0.0235 - val_mse: 0.0010
# Epoch 32/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0175 - mse: 7.4637e-04 - val_loss: 0.0169 - val_mse: 8.9163e-04
# Epoch 33/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0164 - mse: 7.2193e-04 - val_loss: 0.0178 - val_mse: 8.6282e-04
# Epoch 34/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0160 - mse: 7.1631e-04 - val_loss: 0.0180 - val_mse: 9.6917e-04
# Epoch 35/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0160 - mse: 7.3438e-04 - val_loss: 0.0182 - val_mse: 7.9007e-04
# Epoch 36/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0159 - mse: 6.8513e-04 - val_loss: 0.0206 - val_mse: 8.6890e-04
# Epoch 37/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0182 - mse: 7.5273e-04 - val_loss: 0.0202 - val_mse: 0.0011
# Epoch 38/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0162 - mse: 7.2466e-04 - val_loss: 0.0162 - val_mse: 7.8769e-04
# Epoch 39/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0156 - mse: 6.8749e-04 - val_loss: 0.0183 - val_mse: 7.9707e-04
# Epoch 40/40
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0165 - mse: 6.9233e-04 - val_loss: 0.0257 - val_mse: 9.7863e-04

# %%
results = model.predict(x_val)
plt.scatter(range(len(y_val)), y_val, c='g')
plt.scatter(range(len(results)), results, c='r')
plt.title('Validate')
plt.show()
# Out:
# 1/1 [==============================] - 0s 74ms/step

# %% [markdown]
# ### 3.4. Pronóstico de ventas futuras

# %%
ultimosDias = df['2018-11-16':'2018-11-30']
ultimosDias
# Out:
#             unidades
# fecha
# 2018-11-16       152
# 2018-11-17       111
# 2018-11-19       207
# 2018-11-20       206
# 2018-11-21       183
# 2018-11-22       200
# 2018-11-23       187
# 2018-11-24       189
# 2018-11-25        76
# 2018-11-26       276
# 2018-11-27       220
# 2018-11-28       183
# 2018-11-29       251
# 2018-11-30       189

# %%
values = ultimosDias.values
values = values.astype('float32')
# Normalize features
values = values.reshape(-1, 1)  # Esto lo hacemos porque tenemos una sola dimensión
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.drop(reframed.columns[[7]], axis=1, inplace=True)
reframed.head(7)
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7       -0.24      -0.65       0.31       0.30       0.07       0.24
# 8       -0.65       0.31       0.30       0.07       0.24       0.11
# 9        0.31       0.30       0.07       0.24       0.11       0.13
# 10       0.30       0.07       0.24       0.11       0.13      -1.00
# 11       0.07       0.24       0.11       0.13      -1.00       1.00
# 12       0.24       0.11       0.13      -1.00       1.00       0.44
# 13       0.11       0.13      -1.00       1.00       0.44       0.07
#
#     var1(t-1)
# 7        0.11
# 8        0.13
# 9       -1.00
# 10       1.00
# 11       0.44
# 12       0.07
# 13       0.75

# %%
values = reframed.values
x_test = values[6:, :]
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
x_test
# Out:
# array([[[ 0.11000001,  0.13      , -1.        ,  1.        ,
#           0.44000006,  0.06999993,  0.75      ]]], dtype=float32)

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(7, input_shape=(1, 7), activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error', optimizer='Adam', metrics=['mse'])
    model.summary()
    return model


def agregarNuevoValor(x_test, nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1] = nuevoValor
    return x_test

# Crear el modelo con la nueva configuración
model = crear_modeloFF()

results = []
for i in range(7):
    parcial = model.predict(x_test)
    results.append(parcial[0])
    print(x_test)
    x_test = agregarNuevoValor(x_test, parcial[0])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 1, 7)              56
#
#  flatten_3 (Flatten)         (None, 7)                 0
#
#  dense_7 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 60ms/step
# [[[ 0.11000001  0.13       -1.          1.          0.44000006
#     0.06999993  0.75      ]]]
# 1/1 [==============================] - 0s 18ms/step
# [[[ 0.13       -1.          1.          0.44000006  0.06999993
#     0.75       -0.53873956]]]
# 1/1 [==============================] - 0s 18ms/step
# [[[-1.          1.          0.44000006  0.06999993  0.75
#    -0.53873956 -0.44529092]]]
# 1/1 [==============================] - 0s 17ms/step
# [[[ 1.          0.44000006  0.06999993  0.75       -0.53873956
#    -0.44529092  0.04675344]]]
# 1/1 [==============================] - 0s 19ms/step
# [[[ 0.44000006  0.06999993  0.75       -0.53873956 -0.44529092
#     0.04675344  0.70892274]]]
# 1/1 [==============================] - ETA: 0s
# C:\Users\pepel\AppData\Local\Temp\ipykernel_7260\88442686.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test.shape[2]-1] = nuevoValor
# 1/1 [==============================] - 0s 17ms/step
# [[[ 0.06999993  0.75       -0.53873956 -0.44529092  0.04675344
#     0.70892274  0.28659725]]]
# 1/1 [==============================] - 0s 19ms/step
# [[[ 0.75       -0.53873956 -0.44529092  0.04675344  0.70892274
#     0.28659725 -0.34449086]]]

# %%
adimen = [x for x in results]
inverted = scaler.inverse_transform(adimen)
inverted
# Out:
# array([[122.12604557],
#        [131.47090967],
#        [180.67534746],
#        [246.89227894],
#        [204.65972881],
#        [141.55091662],
#        [202.53638184]])

# %%
prediccion1SemanaDiciembre = pd.DataFrame(inverted)
prediccion1SemanaDiciembre.columns = ['pronostico']
prediccion1SemanaDiciembre.plot()
prediccion1SemanaDiciembre.to_csv('pronostico.csv')
